# %% [markdown]
# # DIFA Project - Dynamic Time Warping for Pattern Recognition

# %% [markdown]
# In our project, we apply the Dynamic Time Warping (DTW) algorithm to identify patterns in price time series. The goal is to analyze historical price developments and find similar trends across different time periods or products. This method allows us to make potential predictions about future price movements by recognizing recurring patterns in the data.

# %%
import pandas as pd

# Lade die CSV-Datei (Pfad zum Data-Ordner und Dateinamen anpassen)
data = pd.read_csv('../Data/INDEX_US_SP_500_1year.csv')

# Zeige die ersten 5 Zeilen der Datei an
print(data.head())
# Out:
#          Date      Open      High       Low     Close
# 0  09/16/2024  5,615.21  5,636.05  5,604.53  5,633.09
# 1  09/13/2024  5,603.34  5,636.27  5,601.65  5,626.02
# 2  09/12/2024  5,557.48  5,600.71  5,535.50  5,595.76
# 3  09/11/2024  5,496.42  5,560.41  5,406.96  5,554.13
# 4  09/10/2024  5,490.51  5,497.91  5,441.72  5,495.52
